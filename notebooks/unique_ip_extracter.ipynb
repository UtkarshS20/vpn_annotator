# %%
import ipaddress
import os
import pandas as pd
import json

# Define the input and output folder paths
input_folder = '../data/csv_chunks'  # Path where CSV files are stored
output_folder = '../data/ip_addresses'  # Path where JSON files will be saved

# Ensure the output folder exists
os.makedirs(output_folder, exist_ok=True)
def is_ipv4(ip):
    try:
        return isinstance(ipaddress.ip_address(ip), ipaddress.IPv4Address)
    except ValueError:
        return False

# Loop through each CSV file in the input folder
for file_name in os.listdir(input_folder):
    if file_name.endswith('.csv'):
        file_path = os.path.join(input_folder, file_name)
        
        # Read the CSV file and extract unique IPs
        df = pd.read_csv(file_path, usecols=['CLNT_RMT_IP'])
        
        # Filter for unique IPv4 addresses only
        unique_ipv4_ips = [ip for ip in df['CLNT_RMT_IP'].dropna().unique() if is_ipv4(ip)]

        # Format the data as required
        data = {"ip_address": unique_ipv4_ips}
        
        # Create a JSON file for each CSV file
        json_file_name = f"{os.path.splitext(file_name)[0]}_unique_ipv4_ips.json"
        json_file_path = os.path.join(output_folder, json_file_name)
        
        # Write the data to a JSON file
        with open(json_file_path, 'w') as json_file:
            json.dump(data, json_file, indent=4)

        print(f"Unique IPv4 IPs from {file_name} saved to {json_file_path}")
# Out:
# Unique IPv4 IPs from data_chunk_0.csv saved to ../data/ip_addresses\data_chunk_0_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_1.csv saved to ../data/ip_addresses\data_chunk_1_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_10.csv saved to ../data/ip_addresses\data_chunk_10_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_11.csv saved to ../data/ip_addresses\data_chunk_11_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_12.csv saved to ../data/ip_addresses\data_chunk_12_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_13.csv saved to ../data/ip_addresses\data_chunk_13_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_14.csv saved to ../data/ip_addresses\data_chunk_14_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_15.csv saved to ../data/ip_addresses\data_chunk_15_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_16.csv saved to ../data/ip_addresses\data_chunk_16_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_17.csv saved to ../data/ip_addresses\data_chunk_17_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_18.csv saved to ../data/ip_addresses\data_chunk_18_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_19.csv saved to ../data/ip_addresses\data_chunk_19_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_2.csv saved to ../data/ip_addresses\data_chunk_2_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_20.csv saved to ../data/ip_addresses\data_chunk_20_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_21.csv saved to ../data/ip_addresses\data_chunk_21_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_22.csv saved to ../data/ip_addresses\data_chunk_22_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_23.csv saved to ../data/ip_addresses\data_chunk_23_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_24.csv saved to ../data/ip_addresses\data_chunk_24_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_25.csv saved to ../data/ip_addresses\data_chunk_25_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_26.csv saved to ../data/ip_addresses\data_chunk_26_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_27.csv saved to ../data/ip_addresses\data_chunk_27_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_28.csv saved to ../data/ip_addresses\data_chunk_28_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_29.csv saved to ../data/ip_addresses\data_chunk_29_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_3.csv saved to ../data/ip_addresses\data_chunk_3_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_30.csv saved to ../data/ip_addresses\data_chunk_30_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_31.csv saved to ../data/ip_addresses\data_chunk_31_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_32.csv saved to ../data/ip_addresses\data_chunk_32_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_33.csv saved to ../data/ip_addresses\data_chunk_33_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_34.csv saved to ../data/ip_addresses\data_chunk_34_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_35.csv saved to ../data/ip_addresses\data_chunk_35_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_36.csv saved to ../data/ip_addresses\data_chunk_36_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_37.csv saved to ../data/ip_addresses\data_chunk_37_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_38.csv saved to ../data/ip_addresses\data_chunk_38_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_39.csv saved to ../data/ip_addresses\data_chunk_39_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_4.csv saved to ../data/ip_addresses\data_chunk_4_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_40.csv saved to ../data/ip_addresses\data_chunk_40_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_41.csv saved to ../data/ip_addresses\data_chunk_41_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_42.csv saved to ../data/ip_addresses\data_chunk_42_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_43.csv saved to ../data/ip_addresses\data_chunk_43_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_44.csv saved to ../data/ip_addresses\data_chunk_44_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_45.csv saved to ../data/ip_addresses\data_chunk_45_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_46.csv saved to ../data/ip_addresses\data_chunk_46_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_47.csv saved to ../data/ip_addresses\data_chunk_47_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_48.csv saved to ../data/ip_addresses\data_chunk_48_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_49.csv saved to ../data/ip_addresses\data_chunk_49_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_5.csv saved to ../data/ip_addresses\data_chunk_5_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_50.csv saved to ../data/ip_addresses\data_chunk_50_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_51.csv saved to ../data/ip_addresses\data_chunk_51_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_52.csv saved to ../data/ip_addresses\data_chunk_52_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_53.csv saved to ../data/ip_addresses\data_chunk_53_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_54.csv saved to ../data/ip_addresses\data_chunk_54_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_55.csv saved to ../data/ip_addresses\data_chunk_55_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_56.csv saved to ../data/ip_addresses\data_chunk_56_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_57.csv saved to ../data/ip_addresses\data_chunk_57_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_58.csv saved to ../data/ip_addresses\data_chunk_58_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_59.csv saved to ../data/ip_addresses\data_chunk_59_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_6.csv saved to ../data/ip_addresses\data_chunk_6_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_60.csv saved to ../data/ip_addresses\data_chunk_60_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_61.csv saved to ../data/ip_addresses\data_chunk_61_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_62.csv saved to ../data/ip_addresses\data_chunk_62_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_63.csv saved to ../data/ip_addresses\data_chunk_63_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_64.csv saved to ../data/ip_addresses\data_chunk_64_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_65.csv saved to ../data/ip_addresses\data_chunk_65_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_66.csv saved to ../data/ip_addresses\data_chunk_66_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_67.csv saved to ../data/ip_addresses\data_chunk_67_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_68.csv saved to ../data/ip_addresses\data_chunk_68_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_69.csv saved to ../data/ip_addresses\data_chunk_69_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_7.csv saved to ../data/ip_addresses\data_chunk_7_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_70.csv saved to ../data/ip_addresses\data_chunk_70_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_71.csv saved to ../data/ip_addresses\data_chunk_71_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_72.csv saved to ../data/ip_addresses\data_chunk_72_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_73.csv saved to ../data/ip_addresses\data_chunk_73_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_74.csv saved to ../data/ip_addresses\data_chunk_74_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_75.csv saved to ../data/ip_addresses\data_chunk_75_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_76.csv saved to ../data/ip_addresses\data_chunk_76_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_77.csv saved to ../data/ip_addresses\data_chunk_77_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_8.csv saved to ../data/ip_addresses\data_chunk_8_unique_ipv4_ips.json
# Unique IPv4 IPs from data_chunk_9.csv saved to ../data/ip_addresses\data_chunk_9_unique_ipv4_ips.json

# %%
import os
import json

# Path to the folder containing JSON files
folder_path = '../results'
output_file = 'vpn_ips.txt'

# List to store IPs with is_vpn = True
vpn_ips = []

# Iterate over each file in the folder
for filename in os.listdir(folder_path):
    if filename.endswith('.json'):
        file_path = os.path.join(folder_path, filename)
        
        # Open and load the JSON file
        with open(file_path, 'r') as file:
            data = json.load(file)
            
            # Iterate over each IP in the JSON data
            for ip, info in data.items():
                # Check if 'is_vpn' is true
                if info.get('is_vpn') == True:
                    vpn_ips.append(ip)

# Write the collected IPs to a text file
with open(output_file, 'w') as file:
    for ip in vpn_ips:
        file.write(ip + '\n')

print(f"IPs with is_vpn=true have been written to {output_file}.")
# Out:
# IPs with is_vpn=true have been written to vpn_ips.txt.
